# %% [markdown]
# # UMedia Contents Tutorial Guide
#
# This tutorial guide contains explanations on every folder within the 05a-01_umedia folder and what the 1) contents are, 2) how they operate and 3) where they are posted after they run with the `harvest.py` script. Including the **find_bbox.ipynb** and the process in replacing missing bounding boxes.
#
# > Original created on Feb 5, 2023 by Alexander Danielson (ardumn)

# %% [markdown]
# # 'harvest.py' and find_bbox.ipynb

# %% [markdown]
# ### allRawHarvest_2017-2022.csv

# %% [markdown]
# Screen Shot 2023-02-05 at 14.58.56![image.png](attachment:image.png)
