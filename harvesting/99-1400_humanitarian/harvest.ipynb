# %% [markdown]
# # Aardvark Metadata for HDX
#
# This script aims to harvest metadata in Aardvark version from datasets on [HDX site](https://data.humdata.org).
#
# > Originally created by Gene Cheng [@Ziiiiing]() on Oct 24, 2021

# %%
import csv 
import time
import uuid
import geocoder
import urllib.request
from bs4 import BeautifulSoup

# %% [markdown]
# Before execute the script, you need to manually change the following cell to your own **GeoNames** user account. Or you can register a free one [here](http://www.geonames.org/login)
#
# *Note: according to Terms and Conditions, the hourly limit for personal account is 1000 credits and 1 credit is 1 hit for webservice request.*

# %%
# Manual changes here
geonames_acc = 'geobtaa'

# %% [markdown]
# ### STEP 1: Find All Data Links from Search Page

# %% [markdown]
# It seems like there are less than 200 data published on this site, so we set the `ext_page_size=200` to the `home_url` to get all search results in one page.
#
# Next, we use the **Beautiful Soup** to find and store all data links in a list.

# %%
home_url = "https://data.humdata.org/dataset?ext_geodata=1&groups=usa&q=&sort=if(gt(last_modified%2Creview_date)%2Clast_modified%2Creview_date)%20desc&ext_page_size=600"
home_page = urllib.request.urlopen(home_url).read()
soup = BeautifulSoup(home_page, "html.parser")

# find geodata links
data_urls = []
linkFields = soup.find_all('div', {'class': 'dataset-heading'})
for tag in linkFields:
    url = 'https://data.humdata.org' + tag.find('a')['href']
    data_urls.append(url)

# %% [markdown]
# ### STEP 2: Extract metadata from Each Data Page

# %%
def find_download(files):
    datasets = []
    for file in files:
        download = 'https://data.humdata.org' + file.find('a', href=True)['href']
        ftype = ''
        fsize = ''
        spans = file.find('a', {'class': 'heading'}).find_all('span')
        for span in spans:
            if span['class'] == ['format-label']:
                ftype = span['data-format']
            if span['class'] == ['format-filesize-label']:
                fsize = span.text.strip()[1:-1]
        datasets.append([download, ftype, fsize])
    
    # consider the first shapefile as download file
    for data in datasets:
        if data[1] == 'shp':
            ftype_full = 'Shapefile'
            return data[0], ftype_full, data[2]
    
    # if no shapefile exists, try to find ARC/INFO Grid, GeoTIFF, Geodatabase, Geopackage files instead
    for data in datasets:
        if data[1] in ['arc/info grid', 'geotiff', 'geodatabase', 'geopackage']:
            ftype_full = data[1].capitalize()
            return data[0], ftype_full, data[2]
        
    # else, return nothing
    return '','',''

# %%
# get the bounding box for the given location
# def find_bbox(location):
#     if location == 'World':
#         bbox = '-180,90,180,-90'
#         return bbox
#     # for single place, return bbox directly
#     if len(location.split('|')) == 1:
#         g1 = geocoder.geonames(location, key=geonames_acc)
#         gid = g1.geonames_id
#         g2 = geocoder.geonames(gid, method='details', key=geonames_acc)
#         bbox = g2.bbox
#         w = str(round(bbox['southwest'][1],4))
#         n = str(round(bbox['northeast'][0],4))
#         e = str(round(bbox['northeast'][1],4))
#         s = str(round(bbox['southwest'][0],4))
#         return ','.join((w,n,e,s))
#     # for multiple locations, find a broader bounding box for all places
#     else:
#         places = location.split('|')
#         w_all = 180
#         n_all = -90
#         e_all = -180
#         s_all = 90
#         for place in places:
#             try:
#                 g1 = geocoder.geonames(place, key=geonames_acc)
#                 gid = g1.geonames_id
#                 g2 = geocoder.geonames(gid, method='details', key=geonames_acc)
#                 bbox = g2.bbox
                
#                 w = round(bbox['southwest'][1],4)
#                 n = round(bbox['northeast'][0],4)
#                 e = round(bbox['northeast'][1],4)
#                 s = round(bbox['southwest'][0],4)

#                 if w < w_all:
#                     w_all = w
#                 if n > n_all:
#                     n_all = n
#                 if e > e_all:
#                     e_all = e
#                 if s < s_all:
#                     s_all = s
            
#             except:
#                 continue          

#         return ','.join((str(w_all),str(n_all),str(e_all),str(s_all)))

# %%
def collect_metadata(url):
    data_page = urllib.request.urlopen(url).read()
    soup = BeautifulSoup(data_page, "html.parser")
    metadata = []
    
    alternativeTitle = soup.find('h1', {'class': 'itemTitle dataset-title'}).text.strip()
    title = alternativeTitle
    
    descriptionField = soup.find('div', {'class': 'notes embedded-content'}).find_all('p')
    description = ''.join(x.text.strip() for x in descriptionField)

    creator = soup.find('th', text = 'Contributor').findNext('td').text.strip()

    keywordField = soup.find('th', text = 'Tags').findNext('td').find_all('a')
    keyword = keyword = '|'.join(x.text.strip() for x in keywordField)
    
    try:
        updatedField = soup.find('th', text='Updated').findNext('td').text.strip()
        dd = updatedField.split()[0].zfill(2)
        yyyy = updatedField.split()[2]
        mm = str(time.strptime(updatedField.split()[1], '%B').tm_mon).zfill(2)
        dateIssued = '-'.join((yyyy,mm,dd))
    except:
        dateIssued = ''

    try:
        temporalCoverage = soup.find('th', text='Date of Dataset').findNext('td').text.strip()
        fromY = temporalCoverage.split('-')[0].split()[-1]
        toY = temporalCoverage.split('-')[1].split()[-1]
        dateRange = '-'.join((fromY, toY)) 
    except:
        temporalCoverage = ''
        dateRange = ''
    
    updateFrequency = soup.find('th', text='Expected Update Frequency').findNext('td').text.strip()

    locationField = soup.find('th', text='Location').findNext('td').find_all('a')
    spatialCoverage = '|'.join(x.text.strip() for x in locationField)
#     bbox = find_bbox(spatialCoverage) 
    
    license = soup.find('th', text='License').findNext('td').text.replace('\n', '').replace('\t', '').strip()
    

    files = soup.find_all('li', {'class': 'resource-item'})
    download, formatElement, fileSize = find_download(files)
    
    resourceType = 'Vector data'
    resourceClass = 'Datasets'
    information = url
    identifier = url
    idElement = str(uuid.uuid4())
    isoTopCat = ''
    language = 'eng'
    provider = 'University of Minnesota'
    code = '99-1400'
    memberOf = '99-1400'
    status = 'Active'
    accrualMethod = 'HTML'
    dateAccessioned = time.strftime("%Y-%m-%d")
    rights = ''
    accessRights = 'Public'
    suppressed = 'FALSE'
    childRecord = 'FALSE'
    
    metadata = [title, alternativeTitle, description, language, creator, 
                resourceClass, isoTopCat, keyword, dateIssued,
                temporalCoverage, dateRange, updateFrequency, spatialCoverage, resourceType,
                formatElement, information, download, idElement, identifier, 
                provider, code, memberOf, status, accrualMethod, dateAccessioned, 
                rights, license, accessRights,
                suppressed, childRecord, fileSize]
    
    return metadata

# %%
# iterate each data url to extract metadata
all_metadata = []
count = 0
for url in data_urls:
    count += 1
    print('>>> [{}/{}] harvesting dataset:\n{}'.format(count, len(data_urls), url))
    all_metadata.append(collect_metadata(url))
    # remove datasets without available download files in Shapefile, 
    # ARC/INFO Grid, GeoTIFF, Geodatabase, Geopackage format
    all_metadata = [x for x in all_metadata if x[17]]
# Out:
# >>> [1/584] harvesting dataset:
# https://data.humdata.org/dataset/flood-mapping-in-cantua-creek-california-january-2023
# >>> [2/584] harvesting dataset:
# https://data.humdata.org/dataset/flood-mapping-by-drones-in-merced-california-january-2023
# >>> [3/584] harvesting dataset:
# https://data.humdata.org/dataset/kontur-population-united-states-of-america
# >>> [4/584] harvesting dataset:
# https://data.humdata.org/dataset/kontur-boundaries-united-states
# >>> [5/584] harvesting dataset:
# https://data.humdata.org/dataset/worldpop-population-density-for-united-states-of-america
# >>> [6/584] harvesting dataset:
# https://data.humdata.org/dataset/worldpop-population-counts-for-united-states-of-america
# >>> [7/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_oklahoma_airports
# >>> [8/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_oklahoma_sea_ports
# >>> [9/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_oklahoma_points_of_interest
# >>> [10/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_oklahoma_health_facilities
# >>> [11/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_oklahoma_education_facilities
# >>> [12/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_oklahoma_waterways
# >>> [13/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_oklahoma_financial_services
# >>> [14/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_oklahoma_roads
# >>> [15/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_oklahoma_railways
# >>> [16/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_oklahoma_populated_places
# >>> [17/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_oklahoma_buildings
# >>> [18/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_kansas_airports
# >>> [19/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_kansas_waterways
# >>> [20/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_kansas_sea_ports
# >>> [21/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_kansas_points_of_interest
# >>> [22/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_kansas_health_facilities
# >>> [23/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_kansas_education_facilities
# >>> [24/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_kansas_financial_services
# >>> [25/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_kansas_populated_places
# >>> [26/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_kansas_railways
# >>> [27/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_kansas_roads
# >>> [28/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_kansas_buildings
# >>> [29/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_nebraska_buildings
# >>> [30/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_nebraska_roads
# >>> [31/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_nebraska_airports
# >>> [32/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_nebraska_points_of_interest
# >>> [33/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_nebraska_waterways
# >>> [34/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_nebraska_health_facilities
# >>> [35/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_nebraska_education_facilities
# >>> [36/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_nebraska_financial_services
# >>> [37/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_nebraska_sea_ports
# >>> [38/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_nebraska_populated_places
# >>> [39/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_nebraska_railways
# >>> [40/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_southdakota_health_facilities
# >>> [41/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_southdakota_education_facilities
# >>> [42/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_southdakota_sea_ports
# >>> [43/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_southdakota_financial_services
# >>> [44/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_southdakota_populated_places
# >>> [45/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_southdakota_waterways
# >>> [46/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_southdakota_airports
# >>> [47/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_southdakota_points_of_interest
# >>> [48/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_southdakota_roads
# >>> [49/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_southdakota_railways
# >>> [50/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_southdakota_buildings
# >>> [51/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_northdakota_airports
# >>> [52/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_northdakota_points_of_interest
# >>> [53/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_northdakota_sea_ports
# >>> [54/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_northdakota_waterways
# >>> [55/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_northdakota_health_facilities
# >>> [56/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_northdakota_education_facilities
# >>> [57/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_northdakota_financial_services
# >>> [58/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_northdakota_railways
# >>> [59/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_northdakota_populated_places
# >>> [60/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_northdakota_roads
# >>> [61/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_northdakota_buildings
# >>> [62/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newmexico_airports
# >>> [63/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newmexico_health_facilities
# >>> [64/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newmexico_sea_ports
# >>> [65/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newmexico_education_facilities
# >>> [66/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newmexico_waterways
# >>> [67/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newmexico_railways
# >>> [68/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newmexico_financial_services
# >>> [69/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newmexico_populated_places
# >>> [70/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newmexico_roads
# >>> [71/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newmexico_buildings
# >>> [72/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newmexico_points_of_interest
# >>> [73/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_colorado_airports
# >>> [74/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_colorado_sea_ports
# >>> [75/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_colorado_health_facilities
# >>> [76/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_colorado_education_facilities
# >>> [77/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_colorado_populated_places
# >>> [78/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_colorado_waterways
# >>> [79/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_colorado_financial_services
# >>> [80/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_colorado_railways
# >>> [81/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_colorado_roads
# >>> [82/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_colorado_buildings
# >>> [83/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_colorado_points_of_interest
# >>> [84/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_wyoming_airports
# >>> [85/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_wyoming_points_of_interest
# >>> [86/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_wyoming_waterways
# >>> [87/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_wyoming_education_facilities
# >>> [88/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_wyoming_health_facilities
# >>> [89/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_wyoming_financial_services
# >>> [90/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_wyoming_roads
# >>> [91/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_wyoming_populated_places
# >>> [92/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_wyoming_railways
# >>> [93/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_wyoming_buildings
# >>> [94/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_wyoming_sea_ports
# >>> [95/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_montana_airports
# >>> [96/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_montana_sea_ports
# >>> [97/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_montana_points_of_interest
# >>> [98/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_montana_health_facilities
# >>> [99/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_montana_waterways
# >>> [100/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_montana_financial_services
# >>> [101/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_montana_education_facilities
# >>> [102/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_montana_populated_places
# >>> [103/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_montana_roads
# >>> [104/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_montana_railways
# >>> [105/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_montana_buildings
# >>> [106/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_arizona_airports
# >>> [107/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_arizona_points_of_interest
# >>> [108/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_arizona_health_facilities
# >>> [109/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_arizona_education_facilities
# >>> [110/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_arizona_sea_ports
# >>> [111/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_arizona_financial_services
# >>> [112/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_arizona_railways
# >>> [113/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_arizona_populated_places
# >>> [114/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_arizona_waterways
# >>> [115/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_arizona_roads
# >>> [116/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_arizona_buildings
# >>> [117/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_utah_airports
# >>> [118/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_utah_sea_ports
# >>> [119/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_utah_points_of_interest
# >>> [120/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_utah_health_facilities
# >>> [121/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_utah_waterways
# >>> [122/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_utah_education_facilities
# >>> [123/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_utah_financial_services
# >>> [124/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_utah_railways
# >>> [125/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_utah_roads
# >>> [126/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_utah_populated_places
# >>> [127/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_utah_buildings
# >>> [128/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_california_airports
# >>> [129/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_california_sea_ports
# >>> [130/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_california_financial_services
# >>> [131/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_california_railways
# >>> [132/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_california_waterways
# >>> [133/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_california_health_facilities
# >>> [134/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_california_education_facilities
# >>> [135/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_california_points_of_interest
# >>> [136/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_california_populated_places
# >>> [137/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_california_buildings
# >>> [138/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_california_roads
# >>> [139/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_washington_airports
# >>> [140/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_washington_sea_ports
# >>> [141/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_washington_points_of_interest
# >>> [142/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_washington_health_facilities
# >>> [143/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_washington_education_facilities
# >>> [144/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_washington_populated_places
# >>> [145/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_washington_waterways
# >>> [146/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_washington_railways
# >>> [147/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_washington_roads
# >>> [148/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_washington_buildings
# >>> [149/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_washington_financial_services
# >>> [150/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_nevada_airports
# >>> [151/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_nevada_points_of_interest
# >>> [152/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_nevada_health_facilities
# >>> [153/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_nevada_waterways
# >>> [154/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_nevada_sea_ports
# >>> [155/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_nevada_education_facilities
# >>> [156/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_nevada_financial_services
# >>> [157/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_nevada_populated_places
# >>> [158/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_nevada_roads
# >>> [159/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_nevada_railways
# >>> [160/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_nevada_buildings
# >>> [161/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_orgeon_airports
# >>> [162/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_orgeon_sea_ports
# >>> [163/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_orgeon_points_of_interest
# >>> [164/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_orgeon_health_facilities
# >>> [165/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_orgeon_financial_services
# >>> [166/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_orgeon_education_facilities
# >>> [167/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_orgeon_populated_places
# >>> [168/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_orgeon_waterways
# >>> [169/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_orgeon_railways
# >>> [170/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_orgeon_roads
# >>> [171/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_orgeon_buildings
# >>> [172/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_idaho_airports
# >>> [173/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_idaho_sea_ports
# >>> [174/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_idaho_points_of_interest
# >>> [175/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_idaho_health_facilities
# >>> [176/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_idaho_waterways
# >>> [177/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_idaho_education_facilities
# >>> [178/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_idaho_populated_places
# >>> [179/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_idaho_roads
# >>> [180/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_idaho_financial_services
# >>> [181/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_idaho_railways
# >>> [182/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_idaho_buildings
# >>> [183/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_northalaska_roads
# >>> [184/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_northalaska_buildings
# >>> [185/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_northalaska_airports
# >>> [186/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_northalaska_points_of_interest
# >>> [187/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_northalaska_health_facilities
# >>> [188/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_northalaska_education_facilities
# >>> [189/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_northalaska_sea_ports
# >>> [190/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_northalaska_populated_places
# >>> [191/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_northalaska_waterways
# >>> [192/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_northalaska_financial_services
# >>> [193/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_northalaska_railways
# >>> [194/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_southalaska_airports
# >>> [195/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_southalaska_sea_ports
# >>> [196/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_southalaska_points_of_interest
# >>> [197/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_southalaska_health_facilities
# >>> [198/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_southalaska_education_facilities
# >>> [199/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_southalaska_financial_services
# >>> [200/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_southalaska_populated_places
# >>> [201/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_southalaska_buildings
# >>> [202/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_southalaska_roads
# >>> [203/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_southalaska_railways
# >>> [204/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_southalaska_waterways
# >>> [205/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_southcarolina_airports
# >>> [206/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_southcarolina_sea_ports
# >>> [207/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_southcarolina_points_of_interest
# >>> [208/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_southcarolina_health_facilities
# >>> [209/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_southcarolina_education_facilities
# >>> [210/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_southcarolina_financial_services
# >>> [211/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_southcarolina_populated_places
# >>> [212/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_southcarolina_waterways
# >>> [213/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_southcarolina_railways
# >>> [214/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_southcarolina_roads
# >>> [215/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_southcarolina_buildings
# >>> [216/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_northcarolina_airports
# >>> [217/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_northcarolina_sea_ports
# >>> [218/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_northcarolina_points_of_interest
# >>> [219/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_northcarolina_education_facilities
# >>> [220/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_northcarolina_financial_services
# >>> [221/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_northcarolina_waterways
# >>> [222/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_northcarolina_railways
# >>> [223/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_northcarolina_roads
# >>> [224/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_northcarolina_buildings
# >>> [225/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_northcarolina_health_facilities
# >>> [226/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_northcarolina_populated_places
# >>> [227/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_hawaii_waterways
# >>> [228/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_hawaii_airports
# >>> [229/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_hawaii_points_of_interest
# >>> [230/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_hawaii_health_facilities
# >>> [231/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_hawaii_sea_ports
# >>> [232/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_hawaii_education_facilities
# >>> [233/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_hawaii_roads
# >>> [234/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_hawaii_financial_services
# >>> [235/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_hawaii_railways
# >>> [236/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_hawaii_populated_places
# >>> [237/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_hawaii_buildings
# >>> [238/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_virginia_airports
# >>> [239/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_virginia_sea_ports
# >>> [240/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_virginia_points_of_interest
# >>> [241/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_virginia_health_facilities
# >>> [242/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_virginia_education_facilities
# >>> [243/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_virginia_financial_services
# >>> [244/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_virginia_railways
# >>> [245/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_virginia_populated_places
# >>> [246/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_virginia_roads
# >>> [247/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_virginia_buildings
# >>> [248/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_virginia_waterways
# >>> [249/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_westvirginia_points_of_interest
# >>> [250/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_westvirginia_waterways
# >>> [251/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_westvirginia_airports
# >>> [252/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_westvirginia_sea_ports
# >>> [253/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_westvirginia_health_facilities
# >>> [254/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_westvirginia_education_facilities
# >>> [255/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_westvirginia_roads
# >>> [256/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_westvirginia_financial_services
# >>> [257/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_westvirginia_railways
# >>> [258/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_westvirginia_populated_places
# >>> [259/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_westvirginia_buildings
# >>> [260/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_districtofcolumbia_waterways
# >>> [261/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_districtofcolumbia_airports
# >>> [262/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_districtofcolumbia_sea_ports
# >>> [263/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_districtofcolumbia_points_of_interest
# >>> [264/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_districtofcolumbia_health_facilities
# >>> [265/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_districtofcolumbia_education_facilities
# >>> [266/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_districtofcolumbia_roads
# >>> [267/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_districtofcolumbia_populated_places
# >>> [268/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_districtofcolumbia_financial_services
# >>> [269/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_districtofcolumbia_railways
# >>> [270/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_districtofcolumbia_buildings
# >>> [271/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_maryland_buildings
# >>> [272/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_maryland_airports
# >>> [273/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_maryland_sea_ports
# >>> [274/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_maryland_points_of_interest
# >>> [275/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_maryland_health_facilities
# >>> [276/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_maryland_waterways
# >>> [277/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_maryland_education_facilities
# >>> [278/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_maryland_financial_services
# >>> [279/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_maryland_populated_places
# >>> [280/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_maryland_railways
# >>> [281/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_maryland_roads
# >>> [282/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_delaware_waterways
# >>> [283/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_delaware_airports
# >>> [284/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_delaware_sea_ports
# >>> [285/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_delaware_points_of_interest
# >>> [286/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_delaware_buildings
# >>> [287/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_delaware_financial_services
# >>> [288/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_delaware_health_facilities
# >>> [289/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_delaware_education_facilities
# >>> [290/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_delaware_roads
# >>> [291/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_delaware_populated_places
# >>> [292/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_delaware_railways
# >>> [293/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_pennsylvania_airports
# >>> [294/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_pennsylvania_sea_ports
# >>> [295/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_pennsylvania_health_facilities
# >>> [296/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_pennsylvania_waterways
# >>> [297/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_pennsylvania_education_facilities
# >>> [298/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_pennsylvania_points_of_interest
# >>> [299/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_pennsylvania_financial_services
# >>> [300/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_pennsylvania_railways
# >>> [301/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_pennsylvania_populated_places
# >>> [302/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_pennsylvania_roads
# >>> [303/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_pennsylvania_buildings
# >>> [304/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newyork_buildings
# >>> [305/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newyork_airports
# >>> [306/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newyork_sea_ports
# >>> [307/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newyork_waterways
# >>> [308/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newyork_health_facilities
# >>> [309/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newyork_education_facilities
# >>> [310/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newyork_populated_places
# >>> [311/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newyork_railways
# >>> [312/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newyork_roads
# >>> [313/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newyork_points_of_interest
# >>> [314/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newyork_financial_services
# >>> [315/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_connecticut_airports
# >>> [316/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_connecticut_sea_ports
# >>> [317/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_connecticut_health_facilities
# >>> [318/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_connecticut_education_facilities
# >>> [319/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_connecticut_waterways
# >>> [320/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_connecticut_points_of_interest
# >>> [321/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_connecticut_financial_services
# >>> [322/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_connecticut_roads
# >>> [323/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_connecticut_populated_places
# >>> [324/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_connecticut_railways
# >>> [325/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_connecticut_buildings
# >>> [326/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_rhodeisland_waterways
# >>> [327/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_rhodeisland_points_of_interest
# >>> [328/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_rhodeisland_roads
# >>> [329/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_rhodeisland_buildings
# >>> [330/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_rhodeisland_airports
# >>> [331/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_rhodeisland_sea_ports
# >>> [332/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_rhodeisland_education_facilities
# >>> [333/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_rhodeisland_health_facilities
# >>> [334/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_rhodeisland_financial_services
# >>> [335/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_rhodeisland_railways
# >>> [336/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_rhodeisland_populated_places
# >>> [337/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_massachusetts_buildings
# >>> [338/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_massachusetts_railways
# >>> [339/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_massachusetts_airports
# >>> [340/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_massachusetts_sea_ports
# >>> [341/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_massachusetts_points_of_interest
# >>> [342/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_massachusetts_waterways
# >>> [343/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_massachusetts_financial_services
# >>> [344/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_massachusetts_education_facilities
# >>> [345/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_massachusetts_health_facilities
# >>> [346/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_massachusetts_populated_places
# >>> [347/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_massachusetts_roads
# >>> [348/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_vermont_airports
# >>> [349/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_vermont_sea_ports
# >>> [350/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_vermont_points_of_interest
# >>> [351/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_vermont_health_facilities
# >>> [352/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_vermont_education_facilities
# >>> [353/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_vermont_waterways
# >>> [354/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_vermont_financial_services
# >>> [355/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_vermont_populated_places
# >>> [356/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_vermont_roads
# >>> [357/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_vermont_railways
# >>> [358/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_vermont_buildings
# >>> [359/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newhampshire_airports
# >>> [360/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newhampshire_sea_ports
# >>> [361/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newhampshire_points_of_interest
# >>> [362/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newhampshire_health_facilities
# >>> [363/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newhampshire_education_facilities
# >>> [364/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newhampshire_waterways
# >>> [365/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newhampshire_financial_services
# >>> [366/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newhampshire_roads
# >>> [367/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newhampshire_railways
# >>> [368/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newhampshire_populated_places
# >>> [369/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newhampshire_buildings
# >>> [370/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_maine_airports
# >>> [371/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_maine_sea_ports
# >>> [372/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_maine_points_of_interest
# >>> [373/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_maine_waterways
# >>> [374/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_maine_education_facilities
# >>> [375/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_maine_health_facilities
# >>> [376/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_maine_financial_services
# >>> [377/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_maine_railways
# >>> [378/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_maine_roads
# >>> [379/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_maine_populated_places
# >>> [380/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_maine_buildings
# >>> [381/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_ohio_airports
# >>> [382/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_ohio_waterways
# >>> [383/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_ohio_sea_ports
# >>> [384/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_ohio_points_of_interest
# >>> [385/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_ohio_health_facilities
# >>> [386/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_ohio_financial_services
# >>> [387/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_ohio_education_facilities
# >>> [388/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_ohio_railways
# >>> [389/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_ohio_populated_places
# >>> [390/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_ohio_buildings
# >>> [391/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_ohio_roads
# >>> [392/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_florida_financial_services
# >>> [393/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_florida_education_facilities
# >>> [394/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_florida_health_facilities
# >>> [395/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_florida_railways
# >>> [396/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_florida_sea_ports
# >>> [397/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_florida_airports
# >>> [398/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_florida_waterways
# >>> [399/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_florida_points_of_interest
# >>> [400/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_florida_buildings
# >>> [401/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_florida_roads
# >>> [402/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_florida_populated_places
# >>> [403/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_georgia_airports
# >>> [404/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_georgia_sea_ports
# >>> [405/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_georgia_points_of_interest
# >>> [406/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_georgia_health_facilities
# >>> [407/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_georgia_waterways
# >>> [408/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_georgia_financial_services
# >>> [409/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_georgia_education_facilities
# >>> [410/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_georgia_railways
# >>> [411/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_georgia_populated_places
# >>> [412/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_georgia_buildings
# >>> [413/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_georgia_roads
# >>> [414/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_alabama_points_of_interest
# >>> [415/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_alabama_airports
# >>> [416/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_alabama_sea_ports
# >>> [417/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_alabama_health_facilities
# >>> [418/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_alabama_education_facilities
# >>> [419/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_alabama_waterways
# >>> [420/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_alabama_financial_services
# >>> [421/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_alabama_populated_places
# >>> [422/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_alabama_railways
# >>> [423/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_alabama_buildings
# >>> [424/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_alabama_roads
# >>> [425/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_mississippi_airports
# >>> [426/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_mississippi_sea_ports
# >>> [427/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_mississippi_points_of_interest
# >>> [428/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_mississippi_health_facilities
# >>> [429/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_mississippi_waterways
# >>> [430/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_mississippi_financial_services
# >>> [431/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_mississippi_education_facilities
# >>> [432/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_mississippi_populated_places
# >>> [433/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_mississippi_roads
# >>> [434/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_mississippi_railways
# >>> [435/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_mississippi_buildings
# >>> [436/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_tennessee_airports
# >>> [437/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_tennessee_sea_ports
# >>> [438/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_tennessee_points_of_interest
# >>> [439/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_tennessee_health_facilities
# >>> [440/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_tennessee_waterways
# >>> [441/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_tennessee_education_facilities
# >>> [442/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_tennessee_financial_services
# >>> [443/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_tennessee_railways
# >>> [444/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_tennessee_populated_places
# >>> [445/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_tennessee_roads
# >>> [446/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_tennessee_buildings
# >>> [447/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_kentucky_airports
# >>> [448/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_kentucky_sea_ports
# >>> [449/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_kentucky_points_of_interest
# >>> [450/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_kentucky_health_facilities
# >>> [451/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_kentucky_waterways
# >>> [452/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_kentucky_education_facilities
# >>> [453/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_kentucky_financial_services
# >>> [454/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_kentucky_populated_places
# >>> [455/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_kentucky_railways
# >>> [456/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_kentucky_roads
# >>> [457/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_kentucky_buildings
# >>> [458/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_michigan_airports
# >>> [459/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_michigan_sea_ports
# >>> [460/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_michigan_points_of_interest
# >>> [461/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_michigan_waterways
# >>> [462/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_michigan_health_facilities
# >>> [463/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_michigan_education_facilities
# >>> [464/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_michigan_financial_services
# >>> [465/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_michigan_populated_places
# >>> [466/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_michigan_railways
# >>> [467/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_michigan_roads
# >>> [468/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_michigan_buildings
# >>> [469/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_minnesota_airports
# >>> [470/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_minnesota_sea_ports
# >>> [471/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_minnesota_points_of_interest
# >>> [472/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_minnesota_health_facilities
# >>> [473/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_minnesota_education_facilities
# >>> [474/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_minnesota_financial_services
# >>> [475/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_minnesota_waterways
# >>> [476/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_minnesota_railways
# >>> [477/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_minnesota_roads
# >>> [478/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_minnesota_buildings
# >>> [479/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_minnesota_populated_places
# >>> [480/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_wisconsin_financial_services
# >>> [481/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_wisconsin_education_facilities
# >>> [482/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_wisconsin_sea_ports
# >>> [483/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_wisconsin_health_facilities
# >>> [484/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_wisconsin_airports
# >>> [485/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_wisconsin_points_of_interest
# >>> [486/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_wisconsin_roads
# >>> [487/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_wisconsin_railways
# >>> [488/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_wisconsin_buildings
# >>> [489/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_wisconsin_waterways
# >>> [490/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_wisconsin_populated_places
# >>> [491/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_indiana_airports
# >>> [492/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_indiana_sea_ports
# >>> [493/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_indiana_health_facilities
# >>> [494/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_indiana_waterways
# >>> [495/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_indiana_education_facilities
# >>> [496/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_indiana_points_of_interest
# >>> [497/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_indiana_financial_services
# >>> [498/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_indiana_railways
# >>> [499/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_indiana_populated_places
# >>> [500/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_indiana_roads
# >>> [501/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_indiana_buildings
# >>> [502/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_illinois_airports
# >>> [503/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_illinois_sea_ports
# >>> [504/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_illinois_waterways
# >>> [505/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_illinois_points_of_interest
# >>> [506/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_illinois_health_facilities
# >>> [507/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_illinois_financial_services
# >>> [508/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_illinois_education_facilities
# >>> [509/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_illinois_railways
# >>> [510/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_illinois_populated_places
# >>> [511/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_illinois_roads
# >>> [512/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_illinois_buildings
# >>> [513/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_louisiana_airports
# >>> [514/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_louisiana_sea_ports
# >>> [515/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_louisiana_points_of_interest
# >>> [516/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_louisiana_health_facilities
# >>> [517/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_louisiana_education_facilities
# >>> [518/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_louisiana_waterways
# >>> [519/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_louisiana_financial_services
# >>> [520/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_louisiana_roads
# >>> [521/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_louisiana_populated_places
# >>> [522/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_louisiana_railways
# >>> [523/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_louisiana_buildings
# >>> [524/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_arkansas_airports
# >>> [525/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_arkansas_sea_ports
# >>> [526/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_arkansas_health_facilities
# >>> [527/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_arkansas_waterways
# >>> [528/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_arkansas_education_facilities
# >>> [529/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_arkansas_points_of_interest
# >>> [530/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_arkansas_financial_services
# >>> [531/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_arkansas_roads
# >>> [532/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_arkansas_railways
# >>> [533/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_arkansas_populated_places
# >>> [534/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_arkansas_buildings
# >>> [535/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_missouri_airports
# >>> [536/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_missouri_sea_ports
# >>> [537/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_missouri_health_facilities
# >>> [538/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_missouri_education_facilities
# >>> [539/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_missouri_points_of_interest
# >>> [540/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_missouri_financial_services
# >>> [541/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_missouri_railways
# >>> [542/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_missouri_populated_places
# >>> [543/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_missouri_roads
# >>> [544/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_missouri_buildings
# >>> [545/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_missouri_waterways
# >>> [546/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_iowa_airports
# >>> [547/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_iowa_sea_ports
# >>> [548/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_iowa_points_of_interest
# >>> [549/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_iowa_health_facilities
# >>> [550/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_iowa_education_facilities
# >>> [551/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_iowa_waterways
# >>> [552/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_iowa_financial_services
# >>> [553/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_iowa_railways
# >>> [554/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_iowa_roads
# >>> [555/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_iowa_populated_places
# >>> [556/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_iowa_buildings
# >>> [557/584] harvesting dataset:
# https://data.humdata.org/dataset/worldpop-age-and-sex-structures-for-united-states-of-america
# >>> [558/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newjersey_airports
# >>> [559/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newjersey_sea_ports
# >>> [560/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newjersey_health_facilities
# >>> [561/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newjersey_waterways
# >>> [562/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newjersey_education_facilities
# >>> [563/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newjersey_points_of_interest
# >>> [564/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newjersey_financial_services
# >>> [565/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newjersey_railways
# >>> [566/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newjersey_populated_places
# >>> [567/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newjersey_roads
# >>> [568/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_newjersey_buildings
# >>> [569/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_texas_financial_services
# >>> [570/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_texas_sea_ports
# >>> [571/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_texas_education_facilities
# >>> [572/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_texas_health_facilities
# >>> [573/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_texas_buildings
# >>> [574/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_texas_railways
# >>> [575/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_texas_points_of_interest
# >>> [576/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_texas_waterways
# >>> [577/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_texas_airports
# >>> [578/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_texas_populated_places
# >>> [579/584] harvesting dataset:
# https://data.humdata.org/dataset/hotosm_usa_texas_roads
# >>> [580/584] harvesting dataset:
# https://data.humdata.org/dataset/united-states-high-resolution-population-density-maps-demographic-estimates
# >>> [581/584] harvesting dataset:
# https://data.humdata.org/dataset/cdc-historical-zika-in-the-usa-2015-2018
# >>> [582/584] harvesting dataset:
# https://data.humdata.org/dataset/hawaii-mag6-9-earthquake-4may2018
# >>> [583/584] harvesting dataset:
# https://data.humdata.org/dataset/hurricane-irma-windspeed
# >>> [584/584] harvesting dataset:
# https://data.humdata.org/dataset/tropical-cyclone-irma-17-path-and-wind-speed-zones-as-of-7-september-2017

# %% [markdown]
# ### STEP 3: Write a CSV Report

# %%
fieldnames = ['Title', 'Alternative Title', 'Description', 'Language', 'Creator', 'Resource Class',
              'ISO Topic Categories', 'Keyword', 'Date Issued', 'Temporal Coverage', 'Date Range', 'Update Frequency', 'Spatial Coverage',
              'Resource Type', 'Format', 'Information', 'Download', 'ID', 'Identifier', 'Provider', 'Code', 'Member Of', 'Status',
              'Accrual Method', 'Date Accessioned', 'Rights', 'License', 'Access Rights', 'Suppressed', 'Child Record', 'File Size']

# %%
with open('All_Metadata.csv', 'w') as fw:
    writer = csv.writer(fw)
    writer.writerow(fieldnames)
    writer.writerows(all_metadata)
